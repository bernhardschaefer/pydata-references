# %%
# %run template.ipynb

# %% [markdown]
# ## Exponential distribution

# %%
def p(x, λ):
    return λ*np.exp(-λ*x)

x = np.linspace(0,5,1000)

fig, ax = plt.subplots(figsize=(10,3))
for λ in [.2, 1., 5.]:
    ax.plot(x, p(x,λ), label=λ)
ax.legend()
ax.set_ylim(0, 2)
ax.set_xlim(0, 5);
